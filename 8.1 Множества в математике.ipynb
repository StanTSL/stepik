# %% [markdown]
# ## Тема урока: множества
# 1. Множества в математике
# 2. Числовые множества
#
# Аннотация. Урок посвящен основным понятиям и определениям теории множеств.
#
# ### Множества в математике
# В математике множество – совокупность объектов, понимаемых как единое целое.
#
# При этом предполагается, что объекты данной совокупности можно отличать друг от друга и от объектов, не входящих в эту совокупность. Например, можно говорить:
#
# - о множестве всех студентов данного курса;
# - множестве всех языков программирования;
# - множестве всех натуральных чисел;
#
# - множестве всех точек данного отрезка.
# Студенты данного курса, языки программирования, натуральные числа, точки данного отрезка – **элементы соответствующих множеств**.
#
# #### Обозначения
# Обычно множества обозначают большими латинскими буквами: $X, \, Y, \ldots$, а элементы множеств – латинскими строчными буквами: $x, \, y, \ldots$.
#
# Запись $x \in X$, ($x \notin X$) означает, что x является (не является) элементом множества X.
#
# Элементы множества указываются в фигурных скобках.
#
# Рассмотрим множество вещей: $\{худи, \, кепка, \, футболка\}$. Такое множество содержит три элемента.
#
# ![image.png](attachment:image.png)
#
# #### Конечные и бесконечные множества
# Рассмотрим три множества:
#
# - $A = \{a, b, c, \ldots , z\}$ – множество букв английского алфавита;
# - $B = \{Тимур, \, Руслан, \, Роман, \, Оля\}$ – множество имён авторов данного курса;
# - $N = \{1, 2, 3, 4, 5, \ldots\}$ – множество натуральных чисел.
#
# Первые два множества содержат конечное количество элементов и являются **конечными** множествами. Третье же множество содержит бесконечно много элементов, поэтому и называется **бесконечным** множеством.
#
# Мы используем символ $\ldots$, чтобы показать, что элементы множества продолжаются. Другими словами, символ $\ldots$ означает "и так далее". Символ $\ldots$ можно использовать как в конечных, так и в бесконечных множествах.

# %% [markdown]
# #### Равенство множеств
# Если два множества X и Y состоят из одних и тех же элементов, то они называются равными $X = Y$.
#
# Например, если $X = \{a, b, с, d\}$ и $Y = \{b, d, c, a\}$, то $X = Y$. Обратите внимание, порядок расположения элементов в записи множеств при их сравнении во внимание **не принимается**.
#
# Еще один пример, $X = \{1, 2, 3, 4, 5\}$ и $Y = \{множество \, натуральных \,чисел \, меньших \, 6\}$. Очевидно, такие множества содержат абсолютно одинаковые элементы, поэтому равны.

# %% [markdown]
# #### Подмножество и надмножество
# Если все элементы множества $X$ принадлежат также и множеству $Y$, то говорят, что $X$ является подмножеством $Y$, а записывается это так: $X \subset Y$.
#
# Например, $X = \{1, 2, 3\}, Y = \{1, 2, 3, 4, 5\}$. Так как все элементы множества $X$ содержатся в множестве $Y$, то мы говорим, что множество $X$ является **подмножеством** множества $Y$.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Множество $X = \{1, 2, 3, 6\}$ не является подмножеством множества $Y = \{1, 2, 3, 4, 5\}$, так как элемент $6$ не содержится в $Y$.
#
# Если множество $X$ является подмножеством множества $Y$, то также говорят, что множество $Y$ является **надмножеством** множества $X$, а записывается это так: $Y \supset X$.
#
# Заметим, что **любое множество также является подмножеством** самого себя. Про такое подмножество говорят **нестрогое подмножество**:
#
# - множество $\{1, \, 2, \, 3\}$ является **нестрогим** подмножеством множества $\{1, \, 2, \, 3\}$;
# - множество $\{1, \, 2, \, 3\}$ является **строгим** подмножеством множества $\{1, \, 2, \, 3, \, 4\}$.

# %% [markdown]
# #### Пустое множество
# Для удобства работы с множествами и записи с их помощью различных математических высказываний, вводится понятие множества, не содержащего ни одного элемента. Оно называется **пустым множеством** и обозначается $\varnothing$.
#
# ![image.png](attachment:image.png)
#
# Рассмотрим множество клавиш пианино, находящихся на гитаре. Очевидно такое множество не содержит элементов и является пустым.
#
# ![image-2.png](attachment:image-2.png)
#
# **Примеры пустых множеств**:
#
# - множество лошадей, пасущихся на луне;
# - множество точек пересечения двух параллельных прямых на плоскости;
# - множество квадратных уравнений, имеющих больше двух корней;
# - множество людей, не любящих данный курс (ха-ха).
#
#    **Пустое множество является подмножеством любого множества.**

# %% [markdown]
# ### Примечания
# 1. **Множества** – **неупорядоченные** совокупности, то есть, неважно в каком порядке указаны элементы множества.
#
# 2. Если множество $X$ конечно, то через $|X|$ обозначается количество элементов множества $X$.
#
# 3. Если множество $X$ содержит n элементов, то оно имеет $2^n$
#   подмножеств, включая пустое множество.
#
#   Например, множество $X = \{a, \, b, \, c\}$ содержит 3 элемента и имеет 8 подмножеств:
#
# - $\{\varnothing\}$;
# - $\{a\}$;
# - $\{b\}$;
# - $\{c\}$;
# - $\{a, \, b\}$;
# - $\{a, \, c\}$;
# - $\{b, \, c\}$;
# - $\{a, \, b, \, c\}$.

# %% [markdown]
# 4. Раздел математики, занимающийся множествами, называется **теорией множеств**. Возникла эта теория во второй половине XIX века, главным образом в трудах немецкого математика Г. Кантора. Кантор определял множество как "любое собрание определенных и различимых между собой объектов нашей интуиции или интеллекта, мыслимое как единое целое".

# %% [markdown]
# ### Задачи

# %% [markdown]
# Пусть $X = \{a, b, c, d, e\}$. Сколько строгих подмножеств у множества X? ОТвет 31
#
# Любое множество по отношению к себе является нестрогим подмножеством. А нам надо найти строгие. Считаем сколько всего : 2 в степени количества элементов, т.е. 2 ** 5 и минус 1 (само себя).

# %% [markdown]
# ## Числовые множества
# К основным числовым множествам математики относятся:
#
# - множество натуральных чисел;
# - множество целых чисел;
# - множество рациональных чисел;
# - множество вещественных чисел;
# - множество комплексных чисел.
#
# ### Натуральные числа
# Исторически первыми появились натуральные числа, предназначенные для подсчёта материальных объектов (овец, кур, монет и т.д.). **Множество натуральных чисел** обозначается буквой $\mathbb{N}$ и содержит следующие числа:
# $\mathbb{N} = \{1, \, 2, \, 3, \, 4, \, 5, \ldots\}$.
#
# ![image.png](attachment:image.png)
#
# Обратите внимание, число **ноль не является натуральным числом**.

# %% [markdown]
# ### Целые числа
# Если к множеству натуральных чисел $\mathbb{N}$ присоединить те же числа с противоположным знаком и ноль, то получится **множество целых чисел**. Множество целых чисел обозначается буквой $\mathbb{Z}$ и содержит следующие числа:
# $\mathbb{Z} = \{0, \, \pm 1, \, \pm 2, \, \pm 3, \, \pm 4, \, \pm 5, \ldots\}$.
#
# Множество натуральных чисел является подмножеством множества целых чисел, поскольку каждый элемент множества $\mathbb{N}$ принадлежит множеству $\mathbb{Z}$.
#
# ![image.png](attachment:image.png)
#
# Множество натуральных чисел – **подмножество** множества целых чисел $\mathbb{N} \subset \mathbb{Z}$.

# %% [markdown]
# ### Рациональные числа
# Рациональным числом в математике называется любое число, представимое в виде частного двух целых чисел с отличным от нуля знаменателем. Множество рациональных чисел обозначается буквой $\mathbb{Q}$ и содержит следующие числа:
# $\mathbb{Q} = \left\{\dfrac{m}{n}, \, m \in \mathbb{Z}, \, n \in \mathbb{N} \right\}$.
#
#  Множество целых чисел является **подмножеством** множества рациональных чисел, так как любое целое число можно представить в виде дроби со знаменателем, равным 1.
#
# Любое рациональное число это либо конечная, либо бесконечная периодическая десятичная дробь. К примеру:
# - $\dfrac{1}{2}=0.5$ – конечная непериодическая дробь;
# - $\dfrac{3}{8} = 0.375$ – конечная непериодическая дробь;
# - $\dfrac{1}{3} = 0.(3)$ – бесконечная периодическая десятичная дробь;
# - $\dfrac{7}{11} = 0.(63)$ – бесконечная периодическая десятичная дробь.

# %% [markdown]
# ### Иррациональные числа
# Не все числа в математике можно представить в виде рационального числа. Примером служат числа:
#
# $\sqrt{2} \approx 1.414213562 \ldots$;
#
# $\pi \approx 3.1415926535 \ldots$;
#
# $e \approx 2.71828182845 \ldots$.
#
# Такие числа называются иррациональными и являются бесконечными непериодическими дробями. Иными словами, в «бесконечных хвостах» иррациональных чисел нет никакой закономерности. Иррациональные числа часто обозначают буквой $\mathbb{I}$.

# %% [markdown]
# ### Вещественные числа
# Объединение рациональных и иррациональных чисел образует множество вещественных чисел. Множество вещественных чисел $\mathbb{R}$ определяется так:
# $\mathbb{R} = \mathbb{Q} \cup \mathbb{I}$,
# где символ $\cup$ – означает объединение множеств.
#
# Геометрическая интерпретация множества вещественных чисел – это числовая прямая:
#
# ![image.png](attachment:image.png)
#
# Каждому вещественному числу соответствует определённая точка числовой прямой, и наоборот – каждой точке числовой прямой обязательно соответствует некоторое вещественное число.
#
#    Множество вещественных чисел также называют **множеством действительных чисел**.

# %% [markdown]
# ### Множество комплексных чисел
# Комплексным числом в математике называется любое число, представимое в виде $a + bi$, где a и b – вещественные числа, а $i=\sqrt{-1}$ – мнимая единица. Множество комплексных чисел обозначается буквой $\mathbb{C}$.
#
# Множество вещественных чисел является **подмножеством множества комплексных чисел**, так как любое вещественное число можно представить в виде $a + bi$, где $b = 0$.

# %% [markdown]
# ### Графическая иллюстрация числовых множеств
# Несложно заметить, что каждое следующее множество является надмножеством предыдущего множества, так как содержит все его элементы:
# $\mathbb{N} \subset \mathbb{Z} \subset \mathbb{Q} \subset \mathbb{R} \subset \mathbb{C}$.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Числовые множества при решении уравнений
# Рассмотрим алгебраические уравнения, корнями которых являются натуральные, целые, рациональные, вещественные и комплексные числа:
#
# Уравнение	Корни	Множество чисел	Обозначение
#
# x - 3 = 0,	x = 3	Натуральные числа	$\mathbb{N}$
#
# x + 7 = 0,	x = -7	Целые числа	$\mathbb{Z}$
#
# $4x - 1 = 0,	  x = \dfrac14$ Рациональные числа	$\mathbb{Q}$
#
# $x^2 −2 = 0,	x = \pm \sqrt2$	Вещественные числа	$\mathbb{R}$
#
# $x^2 + 1 = 0,	x = \pm i$	Комплексные числа	$\mathbb{C}$

# %% [markdown]
# #### Примечания
# 1. Почитать подробнее про числовые множества можно тут. https://ru.wikipedia.org/wiki/%D0%A7%D0%B8%D1%81%D0%BB%D0%BE#%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D0%BD%D1%8B%D0%B5_%D1%87%D0%B8%D1%81%D0%BB%D0%BE%D0%B2%D1%8B%D0%B5_%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%B0
#
# 2. Почитать подробнее про комплексные числа можно тут. https://ru.wikipedia.org/wiki/%D0%9A%D0%BE%D0%BC%D0%BF%D0%BB%D0%B5%D0%BA%D1%81%D0%BD%D0%BE%D0%B5_%D1%87%D0%B8%D1%81%D0%BB%D0%BE
